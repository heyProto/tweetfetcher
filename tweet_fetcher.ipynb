# %%
import tweepy
credentials = {'twitter_api_key': "6rUvL84lK0bkBAkRRhO6Wg23r",
               "twitter_api_secret": "HcQkYwGmPZByvrcRp3VdFl2EZP1mYuXahbHj856fHkAufcumTL",
               "twitter_access_token": "885138945041850368-Ttcjlm73tn7ZnpvGeJlL4DoB7C4jdWy",
               "twitter_access_token_secret": "8b1Ws1UmPowyxTKkQrKJ50j7sKBnVlcbyquMDe7Eiepg5",
           }


auth = tweepy.OAuthHandler(credentials['twitter_api_key'],
                           credentials['twitter_api_secret'])
auth.set_access_token(credentials['twitter_access_token'],
                      credentials['twitter_access_token_secret'])

api = tweepy.API(auth)

# %%
import json
tweet_search = api.search(q="#mobbed @IndianExpress")
with open("tweet.json", "w") as f:
    f.write(json.dumps([tweet._json for tweet in tweet_search], sort_keys=True, separators=(',', ': '), indent=4))

# %%
tweets = []
with open("tweet.json", "r") as f:
    tweets = json.loads(f.read)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-93832e1c53d9> in <module>()
#       1 tweets = []
#       2 with open("tweet.json", "r") as f:
# ----> 3     tweets = json.loads(f.read)
#
# /usr/lib/python3.4/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     310     if not isinstance(s, str):
#     311         raise TypeError('the JSON object must be str, not {!r}'.format(
# --> 312                             s.__class__.__name__))
#     313     if s.startswith(u'\ufeff'):
#     314         raise ValueError("Unexpected UTF-8 BOM (decode using utf-8-sig)")
#
# TypeError: the JSON object must be str, not 'builtin_function_or_method'

# %%
api.search_users(q="moiz")
# Out:
# [User(profile_banner_url='https://pbs.twimg.com/profile_banners/15045016/1476942013', _json={'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15045016/1476942013', 'follow_request_sent': False, 'profile_link_color': '1B95E0', 'description': 'Streamlabs. Peanut Labs (acquired by eRewards). Building stuff people want. Twitch variety streamer.', 'default_profile': False, 'time_zone': 'Pacific Time (US & Canada)', 'profile_image_url': 'http://pbs.twimg.com/profile_images/788978341462220800/XqDGrPWC_normal.jpg', 'verified': True, 'profile_text_color': '333333', 'following': False, 'location': 'San Francisco, CA', 'profile_sidebar_border_color': 'FFFFFF', 'utc_offset': -25200, 'friends_count': 294, 'profile_background_tile': True, 'url': 'https://t.co/AJZ5uKLOE4', 'has_extended_profile': False, 'geo_enabled': True, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/788978341462220800/XqDGrPWC_normal.jpg', 'id': 15045016, 'profile_use_background_image': True, 'is_t
# ...

# %%
import json
a = api.search(q="#lynching")
print(json.dumps([status._json for status in a], sort_keys=True, separators=(',', ': '), indent=4))
# Out:
# [
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Wed Aug 16 12:15:35 +0000 2017",
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         24,
#                         35
#                     ],
#                     "text": "Lynchistan"
#                 },
#                 {
#                     "indices": [
#                         36,
#                         45
#                     ],
#                     "text": "lynching"
#                 },
#                 {
#                     "indices": [
#                         46,
#                         55
#                     ],
#                     "text": "LynchRaj"
#                 },
#                 {
#                     "indices": [
#                         56,
#                         69
#                     ],
#                     "text": "Stoplynching"
#                 },
# ...

# %%
import sqlite3

# %%
m = json.dumps(api.search(q="#cow")[0]._json, separators=(',', ': '))

# %%
json.loads(m)["entities"]
# Out:
# {'hashtags': [{'indices': [24, 28], 'text': 'Cow'}],
#  'media': [{'display_url': 'pic.twitter.com/cC1j4XH13w',
#    'expanded_url': 'https://twitter.com/dorchdude/status/897793183484182529/photo/1',
#    'id': 897793022041239552,
#    'id_str': '897793022041239552',
#    'indices': [125, 148],
#    'media_url': 'http://pbs.twimg.com/media/DHWZ_zCXsAAoHSH.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DHWZ_zCXsAAoHSH.jpg',
#    'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1536},
#     'medium': {'h': 1200, 'resize': 'fit', 'w': 900},
#     'small': {'h': 680, 'resize': 'fit', 'w': 510},
#     'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#    'type': 'photo',
#    'url': 'https://t.co/cC1j4XH13w'}],
#  'symbols': [],
#  'urls': [],
#  'user_mentions': [{'id': 314115681,
#    'id_str': '314115681',
#    'indices': [47, 63],
#    'name': 'Plaza Cinema',
#    'screen_name': 'PlazaDorchester'}]}

# %%
print(m)
# Out:
# {"text": "A warm Dorch welcome to #Cow&amp;Apple next to @PlazaDorchester check out the menu &amp; drinks list! About to try a burger! https://t.co/cC1j4XH13w","lang": "en","id": 897793183484182529,"created_at": "Wed Aug 16 12:12:29 +0000 2017","coordinates": null,"possibly_sensitive": false,"extended_entities": {"media": [{"display_url": "pic.twitter.com/cC1j4XH13w","indices": [125,148],"expanded_url": "https://twitter.com/dorchdude/status/897793183484182529/photo/1","id": 897793022041239552,"url": "https://t.co/cC1j4XH13w","id_str": "897793022041239552","media_url_https": "https://pbs.twimg.com/media/DHWZ_zCXsAAoHSH.jpg","media_url": "http://pbs.twimg.com/media/DHWZ_zCXsAAoHSH.jpg","type": "photo","sizes": {"thumb": {"resize": "crop","h": 150,"w": 150},"large": {"resize": "fit","h": 2048,"w": 1536},"small": {"resize": "fit","h": 680,"w": 510},"medium": {"resize": "fit","h": 1200,"w": 900}}},{"display_url": "pic.twitter.com/cC1j4XH13w","indices": [125,148],"expanded_url": "https://t
# ...

# %%
json.loads(m)["id_str"]
# Out:
# '897793183484182529'

# %%
search_string = " OR ".join(["asd"])

# %%
a = api.search(q=search_string)

# %%
a
# Out:
# [Status(text='RT @Autismword: Free #Autism Rating Scale Test https://t.co/yml0gL8ZmD #usa  #Canberra #asd #disability #adhd #AU', retweeted_status=Status(text='Free #Autism Rating Scale Test https://t.co/yml0gL8ZmD #usa  #Canberra #asd #disability #adhd #AU', id=897805156070211584, created_at=datetime.datetime(2017, 8, 16, 13, 0, 4), coordinates=None, source_url='http://twahodvoice.com', possibly_sensitive=False, author=User(id=2211987808, created_at=datetime.datetime(2013, 12, 7, 10, 40, 46), followers_count=1548, verified=False, profile_text_color='333333', utc_offset=None, contributors_enabled=False, lang='en', is_translator=False, profile_image_url='http://pbs.twimg.com/profile_images/378800000840501302/8b9becc8faf13d547a3fa422ed6a24c1_normal.png', is_translation_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/378800000840501302/8b9becc8faf13d547a3fa422ed6a24c1_normal.png', _json={'translator_type': 'none', 'favourites_count': 9, 'default_profile': Tr
# ...

# %%
tweets = json.dumps([status._json for status in a])

# %%
len(tweets)
# Out:
# 65591

# %%
tweets = json.loads(tweets)

# %%
type(tweets)
# Out:
# list

# %%
tweets[0
      ]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Aug 16 13:05:14 +0000 2017',
#  'entities': {'hashtags': [{'indices': [21, 28], 'text': 'Autism'},
#    {'indices': [71, 75], 'text': 'usa'},
#    {'indices': [77, 86], 'text': 'Canberra'},
#    {'indices': [87, 91], 'text': 'asd'},
#    {'indices': [92, 103], 'text': 'disability'},
#    {'indices': [104, 109], 'text': 'adhd'},
#    {'indices': [110, 113], 'text': 'AU'}],
#   'symbols': [],
#   'urls': [{'display_url': 'goo.gl/WpZUGb',
#     'expanded_url': 'http://goo.gl/WpZUGb',
#     'indices': [47, 70],
#     'url': 'https://t.co/yml0gL8ZmD'}],
#   'user_mentions': [{'id': 2211987808,
#     'id_str': '2211987808',
#     'indices': [3, 14],
#     'name': 'Autism Life',
#     'screen_name': 'Autismword'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 897806457915265024,
#  'id_str': '897806457915265024',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
# ...

# %%
conn = sqlite3.connect("tweet-data/tweet-data.db")
c = conn.cursor()

# Uncomment if table has to be made and db is not persisted
# c.execute('''CREATE TABLE tweets
# (tweet text, hashtags text, author text, id_str text, status integer)''')

search_terms = input("Enter Hashtags separated by a comma:\n")
search_terms = search_terms.split(',')
for i in range(len(search_terms)):
    search_terms[i] = search_terms[i].strip(" ")

search_string = " OR ".join(search_terms)
a = api.search(q=search_string)
tweets = json.dumps([status._json for status in a])
tweets = json.loads(tweets)
tweets_array = []
for tweet in tweets:
    # Creates array of all information needed
    hashtags = []
    for each in tweet["entities"]["hashtags"]:
        hashtags.append(each["text"])

    tweets_array.append((tweet["text"],
                         ", ".join(hashtags),
                         tweet["user"]["name"],
                         tweet["id_str"],
                         0))
# Out:
# Enter Hashtags separated by a comma:
# #cow

# %%
api

# %%
api.search(q="#cow")[0]._json
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 17 06:38:03 +0000 2017',
#  'entities': {'hashtags': [{'indices': [76, 86], 'text': 'IndianArt'},
#    {'indices': [87, 96], 'text': 'Painting'},
#    {'indices': [97, 105], 'text': 'ArtWork'},
#    {'indices': [106, 110], 'text': 'Cow'},
#    {'indices': [111, 118], 'text': 'Womens'},
#    {'indices': [119, 131], 'text': 'VillageLife'}],
#   'symbols': [],
#   'urls': [{'display_url': 'indianartideas.in/artwork/11600',
#     'expanded_url': 'https://www.indianartideas.in/artwork/11600',
#     'indices': [52, 75],
#     'url': 'https://t.co/bC8hPFR6aA'}],
#   'user_mentions': [{'id': 53022103,
#     'id_str': '53022103',
#     'indices': [3, 18],
#     'name': 'Indian Art Ideas',
#     'screen_name': 'Indianartideas'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 898071407770255360,
#  'id_str': '898071407770255360',
#  'in_reply_to_screen_name': None,
# ...

# %%
import requests

# %%
r = requests.get("http://13.126.206.16:8000/iframely", params={"url": "https://twitter.com/IndianExpress/status/898148721522638848"})

# %%
r.text
# Out:
# '{"meta":{"title":"The Indian Express on Twitter","author":"The Indian Express","author_url":"https://twitter.com/IndianExpress","site":"Twitter","description":"Scholars say Donald Trump went afoul in lumping Robert E Lee with foundershttps://t.co/wJFE1SIGlU&mdash; The Indian Express (@IndianExpress) August 17, 2017\\n","canonical":"https://twitter.com/IndianExpress/status/898148721522638848"},"links":{"app":[{"html":"<blockquote class=\\"twitter-tweet\\" align=\\"center\\"><p lang=\\"en\\" dir=\\"ltr\\">Scholars say Donald Trump went afoul in lumping Robert E Lee with founders<a href=\\"https://t.co/wJFE1SIGlU\\">https://t.co/wJFE1SIGlU</a></p>&mdash; The Indian Express (@IndianExpress) <a href=\\"https://twitter.com/IndianExpress/status/898148721522638848\\">August 17, 2017</a></blockquote>\\n<script async src=\\"//platform.twitter.com/widgets.js\\" charset=\\"utf-8\\"></script>","type":"text/html","rel":["app","inline","ssl","html5"],"media":{"max-width":550,"aspect-ratio":1}}],"i
# ...

# %%
r.url
# Out:
# 'http://13.126.206.16:8000/iframely?url=https%3A%2F%2Ftwitter.com%2FIndianExpress%2Fstatus%2F898148721522638848'

# %%
g = {
meta: {
title: "Manoj C G on Twitter",
author: "Manoj C G",
author_url: "https://twitter.com/manojcg4u",
site: "Twitter",
description: "@cpimspeak says Kerala HC judgement on @vijayanpinarayi vindication of its stand that Lavlin case was politically motivated. @IndianExpress pic.twitter.com/nS0IVrCwZF&mdash; Manoj C G (@manojcg4u) August 23, 2017 ",
canonical: "https://twitter.com/manojcg4u/status/900301391754690561"
},
links: {
app: [
{
html: "<blockquote class=\"twitter-tweet\" align=\"center\"><p lang=\"en\" dir=\"ltr\"><a href=\"https://twitter.com/cpimspeak\">@cpimspeak</a> says Kerala HC judgement on <a href=\"https://twitter.com/vijayanpinarayi\">@vijayanpinarayi</a> vindication of its stand that Lavlin case was politically motivated. <a href=\"https://twitter.com/IndianExpress\">@IndianExpress</a> <a href=\"https://t.co/nS0IVrCwZF\">pic.twitter.com/nS0IVrCwZF</a></p>&mdash; Manoj C G (@manojcg4u) <a href=\"https://twitter.com/manojcg4u/status/900301391754690561\">August 23, 2017</a></blockquote> <script async src=\"//platform.twitter.com/widgets.js\" charset=\"utf-8\"></script>",
type: "text/html",
rel: [
"app",
"inline",
"ssl",
"html5"
],
media: {
max-width: 550
}
}
],
thumbnail: [],
icon: [
{
href: "https://abs.twimg.com/icons/apple-touch-icon-192x192.png",
rel: [
"apple-touch-icon",
"icon",
"ssl"
],
type: "image/png",
media: {
width: 192,
height: 192
}
},
{
href: "https://abs.twimg.com/a/1501092126/img/t1/favicon.svg",
rel: [
"mask-icon",
"icon",
"ssl"
],
type: "image/svg"
},
{
href: "https://abs.twimg.com/favicons/favicon.ico",
rel: [
"shortcut",
"icon",
"ssl"
],
type: "image/x-icon"
}
]
},
rel: [
"app",
"inline",
"ssl",
"html5"
],
html: "<blockquote class=\"twitter-tweet\" align=\"center\"><p lang=\"en\" dir=\"ltr\"><a href=\"https://twitter.com/cpimspeak\">@cpimspeak</a> says Kerala HC judgement on <a href=\"https://twitter.com/vijayanpinarayi\">@vijayanpinarayi</a> vindication of its stand that Lavlin case was politically motivated. <a href=\"https://twitter.com/IndianExpress\">@IndianExpress</a> <a href=\"https://t.co/nS0IVrCwZF\">pic.twitter.com/nS0IVrCwZF</a></p>&mdash; Manoj C G (@manojcg4u) <a href=\"https://twitter.com/manojcg4u/status/900301391754690561\">August 23, 2017</a></blockquote> <script async src=\"//platform.twitter.com/widgets.js\" charset=\"utf-8\"></script>"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b5727c466b10> in <module>()
#       1 g = {
#       2 meta: {
# ----> 3 title: "Manoj C G on Twitter",
#       4 author: "Manoj C G",
#       5 author_url: "https://twitter.com/manojcg4u",
#
# NameError: name 'title' is not defined
